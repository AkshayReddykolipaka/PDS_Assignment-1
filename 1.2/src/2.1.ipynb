# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data1=pd.read_csv('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/raw_data/StudentsPerformance.csv')

# %%
data1.to_csv('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/clean_data/clean_data.csv')

# %%
data1.to_csv('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/clean_data/processed_data.csv')

# %%
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1['Total'] = data1['math score'] + data1['writing score'] + data1['reading score']
display(data1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
# visualization 1: Box plot of writing scores by Lunch
sns.boxplot(x='lunch', y='writing score', data=data1)
plt.title('Writing Scores by Lunch')
plt.savefig ('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/results/Writing_Score_by_Lunch.png')
plt.show()
# Out:
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data1['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
data1.lunch.value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
# visualization 2: Strip plot of Total and Lunch
l_g= sns.stripplot(x ='lunch', y= 'Total',hue='lunch', data = data1)
l_f= l_g.get_figure()
l_f.savefig("/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/results/lunchimage.png")
# Out:
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\18165\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# visualization 3: Bar plot of test preparation distribution
test_prep_counts = data1['test preparation course'].value_counts()
plt.bar(test_prep_counts.index, test_prep_counts.values)
plt.title('Test Preparation Distribution')
plt.xlabel('Test_Prep')
plt.ylabel('Count')
plt.savefig ('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/results/Test_Prep_distribution.png')
plt.show()

# %%
# visualization 4: Scatter plot of writing scores vs reading scores
plt.scatter(data1['writing score'], data1['reading score'])
plt.title('Writing score vs Reading score')
plt.xlabel('writing score')
plt.ylabel('reading score')
plt.savefig ('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/results/Writing_score_vs_Reading_score.png')
plt.show()

# %%
# visualization 5: Density plot of reading scores by gender 
sns.kdeplot(x='reading score', data=data1, hue='gender', fill=True, alpha=.3)
plt.title('Reading Scores by Gender')
plt.xlabel('Reading Score')
plt.savefig ('/Users/18165/Desktop/principles of data science/PDS_Assignments-1/1.2/results/Reading_Scores_by_Gender.png')
plt.show()
